# %% [markdown]
# # Ovarian cancer data analysis
# Train steamboat model on HGSC data.

# %%
import os
import scanpy as sc
import squidpy as sq
import numpy as np
import scipy as sp
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import json
# Out:
# c:\Users\lshh\miniconda3\envs\py311_torch211_cuda121\Lib\site-packages\dask\dataframe\_pyarrow_compat.py:15: FutureWarning: Minimal version of pyarrow will soon be increased to 14.0.1. You are using 11.0.0. Please consider upgrading.
#   warnings.warn(

# %%
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['mathtext.fontset'] = 'dejavuserif'
plt.rcParams['font.family'] = 'arial'

pltkw = dict(bbox_inches='tight', transparent=True)

# %%
import sys
sys.path.append("..")
import steamboat as sf
import steamboat.tools
import torch
device = 'cuda'

# %%
import importlib
importlib.reload(steamboat.tools)
# Out:
# <module 'steamboat.tools' from 'g:\\Projects\\Steamboat\\revised\\..\\steamboat\\tools.py'>

# %%
# https://www.nature.com/articles/s41590-024-01943-5

# %% [markdown]
# ## Load data

# %%
regenerate = False

h5ad_file = "../../../data/HGSC/ST_Discovery_so.h5ad"
if (not os.path.exists(h5ad_file)) or regenerate:
    adata = sc.read_mtx("G:/data/HGSC/Csv/ST_Discovery_so_counts.mtx").T
    metadata = pd.read_csv("G:/data/HGSC/Csv/ST_Discovery_so_metadata.csv", index_col=0)
    features = pd.read_csv("G:/data/HGSC/Csv/ST_Discovery_so_features.txt", index_col=0, header=None)
    features.index = features.index.str.strip() # remove trailing white space in gene names
    features.index.name = 'gene_symbol'
    adata.obs = metadata
    adata.var = features
    adata.obsm['spatial'] = adata.obs[['x', 'y']].to_numpy()
    adata.write_h5ad("G:/data/HGSC/h5ad/ST_Discovery_so.h5ad")
else:
    adata = sc.read_h5ad(h5ad_file)

# %%
adata.obs
# Out:
#                    orig.ident  nCount_RNA  nFeature_RNA       samples  \
# SMI_T10_F001_c1017        SMI         848           357  SMI_T10_F001
# SMI_T10_F001_c102         SMI         731           319  SMI_T10_F001
# SMI_T10_F001_c1062        SMI         236           155  SMI_T10_F001
# SMI_T10_F001_c1064        SMI         609           300  SMI_T10_F001
# SMI_T10_F001_c1075        SMI         310           174  SMI_T10_F001
# ...                       ...         ...           ...           ...
# SMI_T14_F020_c5758        SMI         100            63  SMI_T14_F020
# SMI_T14_F020_c734         SMI         141            88  SMI_T14_F020
# SMI_T14_F020_c875         SMI          78            60  SMI_T14_F020
# SMI_T14_F020_c3288        SMI         104            58  SMI_T14_F020
# SMI_T14_F020_c2963        SMI         102            54  SMI_T14_F020
#
#                    patients sites_binary  cell.types  cell.subtypes  \
# SMI_T10_F001_c1017    HGSC1       Adnexa   Malignant      Malignant
# SMI_T10_F001_c102     HGSC1       Adnexa   Malignant      Malignant
# SMI_T10_F001_c1062    HGSC1       Adnexa   Malignant      Malignant
# SMI_T10_F001_c1064    HGSC1       Adnexa   Malignant      Malignant
# SMI_T10_F001_c1075    HGSC1       Adnexa   Malignant      Malignant
# ...                     ...          ...         ...            ...
# SMI_T14_F020_c5758   HGSC89      Omentum    TNK.cell  CD4.T.cell.DN
# SMI_T14_F020_c734    HGSC89      Omentum  Fibroblast     Fibroblast
# SMI_T14_F020_c875    HGSC89      Omentum   Malignant      Malignant
# SMI_T14_F020_c3288   HGSC89      Omentum  Fibroblast     Fibroblast
# SMI_T14_F020_c2963   HGSC89      Omentum    Monocyte       Monocyte
#
#                             x         y
# SMI_T10_F001_c1017  1493.3500  3151.233
# SMI_T10_F001_c102   2623.2000  3607.450
# SMI_T10_F001_c1062   850.5670  3143.833
# SMI_T10_F001_c1064  3222.7300  3152.586
# SMI_T10_F001_c1075    78.0125  3179.012
# ...                       ...       ...
# SMI_T14_F020_c5758  5170.4400   431.900
# SMI_T14_F020_c734    768.7000  3188.400
# SMI_T14_F020_c875     42.5833  3070.350
# SMI_T14_F020_c3288    48.9889  1751.740
# SMI_T14_F020_c2963  3696.3000  1917.450
#
# [491792 rows x 10 columns]

# %%
TNK_info = adata.obs[adata.obs['cell.types'] == 'Monocyte']
TNK_info['cell.subtypes'].value_counts()
# Out:
# cell.subtypes
# Monocyte            35182
# B.cell                  0
# B.cell_LC               0
# Treg                    0
# T.cell.DP_LC            0
# T.cell.DP               0
# T.B.cell_LC             0
# T.B.cell                0
# NK.cell_LC              0
# NK.cell                 0
# Monocyte_LC             0
# Mast.cell_LC            0
# Mast.cell               0
# Malignant_LC            0
# Malignant               0
# Fibroblast_LC           0
# Fibroblast              0
# Endothelial_LC          0
# Endothelial             0
# CD8.T.cell_LC           0
# CD8.T.cell              0
# CD4.T.cell_LC           0
# CD4.T.cell.DN_LC        0
# CD4.T.cell.DN           0
# CD4.T.cell              0
# Treg_LC                 0
# Name: count, dtype: int64

# %%
## Metadata and gene sets

sample_metadata = pd.read_excel("../../../data/HGSC/sample_metadata.xlsx", index_col=0, sheet_name='Table 2b', skiprows=1)
sample_metadata = sample_metadata[sample_metadata['dataset'] == 'Discovery']

celltype_signatures = pd.read_excel("G:/data/HGSC/sample_metadata.xlsx", sheet_name='Table 3a', skiprows=2)
mtil_signautures = pd.read_excel("G:/data/HGSC/sample_metadata.xlsx", sheet_name='Table 6a', skiprows=2)
desmoplasia_signautures = pd.read_excel("G:/data/HGSC/sample_metadata.xlsx", sheet_name='Table 5a', skiprows=2)

def purge_gene_sets(df, prefix=''):
    res = {}
    for i in df.columns:
        res[prefix + i] = df[i].dropna().tolist()
    return res
celltype_signatures = pd.read_excel("G:/data/HGSC/sample_metadata.xlsx", index_col=0, sheet_name='Table 3b', skiprows=2).iloc[:, :-3]
genesets = (purge_gene_sets(celltype_signatures, 'sig_') | 
            purge_gene_sets(mtil_signautures, 'mtil_') | 
            purge_gene_sets(mtil_signautures, 'mtil_'))
genesets.keys()
del genesets['sig_Mast.cell']

sample_metadata
# Out:
#                 dataset platform  n_cells  median_tpc    mean_tpc     TMA  \
# profile
# SMI_T10_F001  Discovery      SMI     5660       205.0  238.675618  TMA 10
# SMI_T10_F002  Discovery      SMI     8821       364.0  393.318671  TMA 10
# SMI_T10_F003  Discovery      SMI     2881       300.0  445.154460  TMA 10
# SMI_T10_F004  Discovery      SMI     3145       286.0  376.895390  TMA 10
# SMI_T10_F005  Discovery      SMI     2187       165.0  267.202561  TMA 10
# ...                 ...      ...      ...         ...         ...     ...
# SMI_T14_F016  Discovery      SMI     2744       209.0  288.211735  TMA 14
# SMI_T14_F017  Discovery      SMI     3376       276.0  368.816647  TMA 14
# SMI_T14_F018  Discovery      SMI     9961       189.0  210.500452  TMA 14
# SMI_T14_F019  Discovery      SMI     3298       205.0  271.453305  TMA 14
# SMI_T14_F020  Discovery      SMI     6214       381.0  406.158191  TMA 14
#
#              patients sites_binary   age stage  ... fu_time2  \
# profile                                         ...
# SMI_T10_F001    HGSC1       Adnexa  58.0   III  ...    775.0
# SMI_T10_F002    HGSC7       Adnexa  58.0   III  ...   1013.0
# SMI_T10_F003    HGSC8       Adnexa  65.0    IV  ...    781.0
# SMI_T10_F004   HGSC13      Omentum  67.0   III  ...    840.0
# SMI_T10_F005   HGSC15       Adnexa  33.0    IV  ...    845.0
# ...               ...          ...   ...   ...  ...      ...
# SMI_T14_F016   HGSC61      Omentum  70.0   III  ...   1955.0
# SMI_T14_F017   HGSC63      Omentum  71.0   III  ...    407.0
# SMI_T14_F018   HGSC89       Adnexa  53.0   III  ...   1729.0
# SMI_T14_F019   HGSC91       Adnexa  67.0   III  ...   1925.0
# SMI_T14_F020   HGSC89      Omentum  53.0   III  ...   1729.0
#
#                                               outcome     pfs BRCA1_Somatic  \
# profile
# SMI_T10_F001                                    Alive   775.0            WT
# SMI_T10_F002                                    Alive  1013.0             P
# SMI_T10_F003                                    Alive   200.0            WT
# SMI_T10_F004                           Dead (disease)   161.0            WT
# SMI_T10_F005                                    Alive   845.0            WT
# ...                                               ...     ...           ...
# SMI_T14_F016                                    Alive  1955.0            WT
# SMI_T14_F017  D/c to hospice (likely dead of disease)   297.0            WT
# SMI_T14_F018                           Dead (disease)   412.0           NaN
# SMI_T14_F019  D/c to hospice (likely dead of disease)   867.0            WT
# SMI_T14_F020                           Dead (disease)   412.0           NaN
#
#               BRCA2_Somatic  TP53_Somatic BRCA1_Germline  BRCA2_Germline  \
# profile
# SMI_T10_F001              P             P             US              US
# SMI_T10_F002             WT            LP             US              US
# SMI_T10_F003             WT             P             US              US
# SMI_T10_F004             WT             P             US              US
# SMI_T10_F005             WT             P              P              US
# ...                     ...           ...            ...             ...
# SMI_T14_F016             WT             P             US              US
# SMI_T14_F017             WT             P             US              US
# SMI_T14_F018            NaN           NaN            NaN             NaN
# SMI_T14_F019             WT             P             US              US
# SMI_T14_F020            NaN           NaN            NaN             NaN
#
#              TP53_Germline   tmb
# profile
# SMI_T10_F001            US  6.80
# SMI_T10_F002            US  0.53
# SMI_T10_F003            US  3.16
# SMI_T10_F004            US  2.63
# SMI_T10_F005            US  2.63
# ...                    ...   ...
# SMI_T14_F016            US  1.10
# SMI_T14_F017            US  0.50
# SMI_T14_F018           NaN   NaN
# SMI_T14_F019            US  0.50
# SMI_T14_F020           NaN   NaN
#
# [100 rows x 25 columns]

# %%
## Find untreated, adnexa samples

columns_of_interest = ['sites_binary', 'stage', 'treatment']
fig, axes = plt.subplots(1, len(columns_of_interest), figsize=(len(columns_of_interest) * 1.5, 3))
for i, column in enumerate(columns_of_interest):
    sample_metadata[column].value_counts().plot(kind='bar', ax=axes[i])
    axes[i].set_title(column)
plt.tight_layout()

mask = (sample_metadata['sites_binary'] == 'Adnexa') & (sample_metadata['treatment'] == 'Untreated')
samples_of_interest = sample_metadata.index[mask].tolist()

all_adata = adata[adata.obs['samples'].isin(samples_of_interest)].copy()
all_adata.obs['cell.types.nolc'] = all_adata.obs['cell.types'].str.replace('_LC', '')

# %%
# selected_samples = np.random.choice(all_adata.obs['samples'].unique(), size=10, replace=False)
# all_adata = all_adata[all_adata.obs['samples'].isin(selected_samples)].copy()

# %% [markdown]
# ### Process data to create torch dataset

# %%
# Separate individual slides
adatas = []
for i in all_adata.obs['samples'].unique():
    temp = all_adata[all_adata.obs['samples'] == i].copy()
    if temp.shape[0] < 100:
        continue
    adatas.append(temp)
    adatas[-1].obs['global'] = 0

# normalize and log transformation
adatas = sf.prep_adatas(adatas, norm=True, log1p=True, scale=False, renorm=False)

# create torch dataset
dataset = sf.make_dataset(adatas, sparse_graph=True, regional_obs=['global'])
# Out:
#   0%|          | 0/27 [00:00<?, ?it/s]
# Using ['global'] as regional annotations.
#   0%|          | 0/27 [00:00<?, ?it/s]

# %%
print(*adata.obs['cell.types'].unique())
# Out:
# Malignant Fibroblast Monocyte TNK.cell Malignant_LC B.cell Endothelial_LC Endothelial Fibroblast_LC TNK.cell_LC B.cell_LC Monocyte_LC Mast.cell_LC Mast.cell

# %%
immune_types = ['TNK.cell', 'B.cell', 'Monocyte', 'Mast.cell']
fibroblast_types = ['Fibroblast']

# %%
cuda_dataset = None

load_data_into_gpu = True # if you run into OOM on GPU, set this to False
if device == 'cuda' and load_data_into_gpu:
    cuda_dataset = dataset.to('cuda')

# %%
n_heads = 25

sf.set_random_seed(0)
model = sf.Steamboat(adata.var_names.tolist(), n_heads=n_heads, n_scales=3)
model = model.to(device)

use_dataset = cuda_dataset
if use_dataset is None:
    use_dataset = dataset

model.load_state_dict(torch.load('../examples/saved_models/hgsc.pth', weights_only=True), strict=False)

# model.fit(cuda_dataset, entry_masking_rate=0.1, feature_masking_rate=0.1,
#           max_epoch=10000, 
#           loss_fun=torch.nn.MSELoss(reduction='sum'),
#           opt=torch.optim.Adam, opt_args=dict(lr=0.1), stop_eps=1e-3, report_per=200, stop_tol=200, device=device)
# Out:
# c:\Users\lshh\miniconda3\envs\py311_torch211_cuda121\Lib\site-packages\torch\_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# <All keys matched successfully>

# %%
sf.tools.calc_obs(adatas, dataset, model, get_recon=True)
# Out:
#   0%|          | 0/27 [00:00<?, ?it/s]

# %%
# find Fibroblast spots that do NOT neighbor any Monocyte (per-sample)
fibro_no_monocyte_by_sample = {}

for ad in adatas:
    sample = ad.obs['samples'].unique()[0]

    # find a spatial connectivity matrix (same logic as earlier)
    conn = None
    if 'spatial_connectivities' in ad.obsp:
        conn = ad.obsp['spatial_connectivities']
    elif 'connectivities' in ad.obsp:
        conn = ad.obsp['connectivities']
    elif 'spatial_neighbors' in ad.uns and 'connectivities' in ad.uns['spatial_neighbors']:
        conn = ad.uns['spatial_neighbors']['connectivities']

    if conn is None:
        print(f"{sample}: no spatial connectivity matrix found, skipping")
        continue

    # ensure CSR
    if sp.sparse.issparse(conn):
        conn = conn.tocsr()
    else:
        conn = sp.sparse.csr_matrix(conn)

    # boolean masks
    monocyte_mask = ad.obs['cell.subtypes'].astype(str).isin(['Monocyte']).values
    fibro_mask = ad.obs['cell.types'].astype(str).isin(['Fibroblast']).values

    if monocyte_mask.sum() == 0:
        # no monocytes in this sample -> all fibroblasts have no monocyte neighbors
        fibro_idx = np.flatnonzero(fibro_mask)
    else:
        # number of edges from each cell to monocytes
        to_monocyte_counts = np.asarray(conn[:, monocyte_mask].sum(axis=1)).squeeze()
        # fibroblasts with zero monocyte neighbors
        fibro_no_mon_mask = fibro_mask & (to_monocyte_counts == 0)
        fibro_idx = np.flatnonzero(fibro_no_mon_mask)

    # record in AnnData and dict
    ad.obs['fib_no_monocyte_neighbor'] = False
    if len(fibro_idx) > 0:
        ad.obs.loc[ad.obs.index[fibro_idx], 'fib_no_monocyte_neighbor'] = True

    fibro_no_monocyte_by_sample[sample] = fibro_idx
    print(f"{sample}: {len(fibro_idx)} Fibroblast(s) without Monocyte neighbor (n_cells={ad.shape[0]})")

# fibro_no_monocyte_by_sample now maps sample -> numpy array of row indices for fibroblasts without monocyte neighbors
# Out:
# SMI_T10_F001: 426 Fibroblast(s) without Monocyte neighbor (n_cells=5660)
# SMI_T10_F002: 2 Fibroblast(s) without Monocyte neighbor (n_cells=8821)
# SMI_T10_F006: 131 Fibroblast(s) without Monocyte neighbor (n_cells=5295)
# SMI_T10_F014: 617 Fibroblast(s) without Monocyte neighbor (n_cells=5944)
# SMI_T11_F001: 31 Fibroblast(s) without Monocyte neighbor (n_cells=2212)
# SMI_T11_F002: 154 Fibroblast(s) without Monocyte neighbor (n_cells=3267)
# SMI_T11_F004: 205 Fibroblast(s) without Monocyte neighbor (n_cells=8088)
# SMI_T11_F008: 105 Fibroblast(s) without Monocyte neighbor (n_cells=2967)
# SMI_T11_F009: 9 Fibroblast(s) without Monocyte neighbor (n_cells=4311)
# SMI_T11_F011: 0 Fibroblast(s) without Monocyte neighbor (n_cells=3876)
# SMI_T11_F020: 53 Fibroblast(s) without Monocyte neighbor (n_cells=6266)
# SMI_T12_F005: 65 Fibroblast(s) without Monocyte neighbor (n_cells=8201)
# SMI_T12_F007: 254 Fibroblast(s) without Monocyte neighbor (n_cells=7039)
# SMI_T12_F009: 380 Fibroblast(s) without Monocyte neighbor (n_cells=9875)
# SMI_T12_F013: 144 Fibroblast(s) without Monocyte neighbor (n_cells=5203)
# SMI_T12_F015: 11 Fibroblast(s) without Monocyte neighbor (n_cells=7804)
# SMI_T12_F018: 90 Fibroblast(s) without Monocyte neighbor (n_cells=6182)
# SMI_T13_F005: 64 Fibroblast(s) without Monocyte neighbor (n_cells=5728)
# SMI_T13_F009: 167 Fibroblast(s) without Monocyte neighbor (n_cells=3500)
# SMI_T13_F011: 56 Fibroblast(s) without Monocyte neighbor (n_cells=8340)
# SMI_T13_F018: 0 Fibroblast(s) without Monocyte neighbor (n_cells=4984)
# SMI_T13_F019: 307 Fibroblast(s) without Monocyte neighbor (n_cells=3917)
# SMI_T14_F002: 12 Fibroblast(s) without Monocyte neighbor (n_cells=7151)
# SMI_T14_F005: 179 Fibroblast(s) without Monocyte neighbor (n_cells=8160)
# SMI_T14_F015: 227 Fibroblast(s) without Monocyte neighbor (n_cells=5912)
# SMI_T14_F018: 18 Fibroblast(s) without Monocyte neighbor (n_cells=9961)
# SMI_T14_F019: 719 Fibroblast(s) without Monocyte neighbor (n_cells=3298)

# %%
# mark neighbors of fibroblasts that have no monocyte neighbors
for ad in adatas:
    sample = ad.obs['samples'].unique()[0]
    fibro_idx = fibro_no_monocyte_by_sample.get(sample, np.array([], dtype=int))

    # default column
    ad.obs['neighbor_of_fib_no_monocyte'] = False

    if len(fibro_idx) == 0:
        print(f"{sample}: no fibro_no_monocyte cells -> nothing to mark")
        continue

    # get connectivity (same logic as before)
    conn = None
    if 'spatial_connectivities' in ad.obsp:
        conn = ad.obsp['spatial_connectivities']
    elif 'connectivities' in ad.obsp:
        conn = ad.obsp['connectivities']
    elif 'spatial_neighbors' in ad.uns and 'connectivities' in ad.uns['spatial_neighbors']:
        conn = ad.uns['spatial_neighbors']['connectivities']

    if conn is None:
        print(f"{sample}: no spatial connectivity matrix found, skipping")
        continue

    # ensure CSR
    if sp.sparse.issparse(conn):
        conn = conn.tocsr()
    else:
        conn = sp.sparse.csr_matrix(conn)

    # neighbors of the selected fibroblast rows
    neigh_cols = conn[fibro_idx].nonzero()[1]  # column indices are neighbor cell indices
    neigh_cols = np.unique(neigh_cols)

    # avoid marking the fibro cells themselves (if present)
    neigh_cols = neigh_cols[~np.isin(neigh_cols, fibro_idx)]

    if len(neigh_cols) > 0:
        ad.obs.loc[ad.obs.index[neigh_cols], 'neighbor_of_fib_no_monocyte'] = True

    print(f"{sample}: marked {len(neigh_cols)} neighbor cells of {len(fibro_idx)} fibro_no_monocyte cells")
# Out:
# SMI_T10_F001: marked 807 neighbor cells of 426 fibro_no_monocyte cells
# SMI_T10_F002: marked 12 neighbor cells of 2 fibro_no_monocyte cells
# SMI_T10_F006: marked 574 neighbor cells of 131 fibro_no_monocyte cells
# SMI_T10_F014: marked 702 neighbor cells of 617 fibro_no_monocyte cells
# SMI_T11_F001: marked 168 neighbor cells of 31 fibro_no_monocyte cells
# SMI_T11_F002: marked 396 neighbor cells of 154 fibro_no_monocyte cells
# SMI_T11_F004: marked 739 neighbor cells of 205 fibro_no_monocyte cells
# SMI_T11_F008: marked 356 neighbor cells of 105 fibro_no_monocyte cells
# SMI_T11_F009: marked 66 neighbor cells of 9 fibro_no_monocyte cells
# SMI_T11_F011: no fibro_no_monocyte cells -> nothing to mark
# SMI_T11_F020: marked 243 neighbor cells of 53 fibro_no_monocyte cells
# SMI_T12_F005: marked 335 neighbor cells of 65 fibro_no_monocyte cells
# SMI_T12_F007: marked 698 neighbor cells of 254 fibro_no_monocyte cells
# SMI_T12_F009: marked 1159 neighbor cells of 380 fibro_no_monocyte cells
# SMI_T12_F013: marked 423 neighbor cells of 144 fibro_no_monocyte cells
# SMI_T12_F015: marked 74 neighbor cells of 11 fibro_no_monocyte cells
# SMI_T12_F018: marked 354 neighbor cells of 90 fibro_no_monocyte cells
# SMI_T13_F005: marked 168 neighbor cells of 64 fibro_no_monocyte cells
# SMI_T13_F009: marked 431 neighbor cells of 167 fibro_no_monocyte cells
# SMI_T13_F011: marked 318 neighbor cells of 56 fibro_no_monocyte cells
# SMI_T13_F018: no fibro_no_monocyte cells -> nothing to mark
# SMI_T13_F019: marked 1317 neighbor cells of 307 fibro_no_monocyte cells
# SMI_T14_F002: marked 63 neighbor cells of 12 fibro_no_monocyte cells
# SMI_T14_F005: marked 480 neighbor cells of 179 fibro_no_monocyte cells
# SMI_T14_F015: marked 316 neighbor cells of 227 fibro_no_monocyte cells
# SMI_T14_F018: marked 138 neighbor cells of 18 fibro_no_monocyte cells
# SMI_T14_F019: marked 915 neighbor cells of 719 fibro_no_monocyte cells

# %%
perturbed_adatas = [adata.copy() for adata in adatas]

np.random.seed(0)

# keep original cell types
for ad in perturbed_adatas:
    if 'cell.types_orig' not in ad.obs.columns:
        ad.obs['cell.types_orig'] = ad.obs['cell.types'].astype(object)

for ad in perturbed_adatas:
    replace_mask = ad.obs['neighbor_of_fib_no_monocyte']
    replace_idx = np.flatnonzero(replace_mask.values)
    n_replace = len(replace_idx) // 2
    # print(n_replace)
    if n_replace <= 0:
        continue

    replace_idx = np.random.choice(replace_idx, size=n_replace, replace=False)

    # try sampling immune cells from the same slide
    immune_mask = ad.obs['cell.subtypes'].astype(str).isin(['Monocyte'])
    immune_idx = np.flatnonzero(immune_mask.values)

    if len(immune_idx) > 0:
        sampled_from_idx = np.random.choice(immune_idx, size=n_replace, replace=True)
        sampled_X = ad.X[sampled_from_idx].toarray() if sp.sparse.issparse(ad.X) else np.array(ad.X[sampled_from_idx])
        sampled_types = ad.obs['cell.types'].iloc[sampled_from_idx].tolist()
    else:
        print(f"No immune cells found in sample {ad.obs['samples'].unique()[0]}. Ignore.")
        continue

    # ensure dense array for assignment (assigning back to ad.X as dense)
    X_dense = ad.X.toarray() if sp.sparse.issparse(ad.X) else np.array(ad.X)
    X_dense[replace_idx] = sampled_X
    ad.X = X_dense

    # update obs: set replaced cells to sampled immune types and mark them
    ad.obs.loc[ad.obs.index[replace_idx], 'cell.types'] = sampled_types
    ad.obs['replaced'] = False
    ad.obs.loc[ad.obs.index[replace_idx], 'replaced'] = True

# finished

perturbed_dataset = sf.make_dataset(perturbed_adatas, sparse_graph=True, regional_obs=['global'])
sf.tools.calc_obs(perturbed_adatas, perturbed_dataset, model, get_recon=True)
# Out:
# Using ['global'] as regional annotations.
#   0%|          | 0/27 [00:00<?, ?it/s]
#   0%|          | 0/27 [00:00<?, ?it/s]

# %%
genesets = {}

path = "G:/Projects/Steamboat/revised/selected_genesets"

for filename in os.listdir(path):
    with open(os.path.join(path, filename), 'r', encoding='utf-8') as f:
        json_data = json.load(f)
        for k in json_data:
            genesets[k] = json_data[k]['geneSymbols']

print(*genesets.keys(), sep='\n')
# Out:
# HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION
# HALLMARK_INFLAMMATORY_RESPONSE
# HALLMARK_TGF_BETA_SIGNALING
# KEGG_CYTOKINE_CYTOKINE_RECEPTOR_INTERACTION
# REACTOME_CYTOKINE_SIGNALING_IN_IMMUNE_SYSTEM

# %%
# Score each sample (AnnData in `adatas`) for the inflammatory gene set restricted to immune cells.
def compute_geneset_scores(adatas, obs, measure_subset, geneset, obsm=None):
    if not isinstance(measure_subset, list):
        measure_subset = [measure_subset]
    results = []
    for ad in adatas:
        sample = ad.obs['samples'].unique()[0]
        measure_mask = ad.obs[obs].isin(measure_subset)
        n_measure = int(measure_mask.sum())
        pct_measure = n_measure / ad.shape[0] * 100.0
        # intersect genes with var_names
        genes_in_data = [g for g in geneset if g in ad.var_names]
        if len(genes_in_data) == 0 or n_measure == 0:
            results.append({
                'sample': sample,
                'n_measure_cells': n_measure,
                'n_genes_used': len(genes_in_data),
                'mean_measure_score': np.nan,
                'median_measure_score': np.nan,
                'std_measure_score': np.nan,
                'mean_notmeasure_score': np.nan,
                'score_diff_measure_minus_notmeasure': np.nan,
                'ttest_pval': np.nan
            })
            continue

        # compute per-spot gene set score (adds ad.obs['inflammatory_score'])
        # sc.tl.score_genes(ad, gene_list=genes_in_data, score_name='inflammatory_score', use_raw=False)
        
        # scores = ad.obs['inflammatory_score']
        if obsm is None:
            scores = pd.Series(np.array(ad[:, genes_in_data].X.mean(axis=1)).squeeze(), index=ad.obs.index)  # mean expression of the gene set
        else:
            scores = pd.Series(np.array(ad.obsm['X_recon'][:, ad.var_names.isin(genes_in_data)].mean(axis=1)).squeeze(), index=ad.obs.index)  # mean expression of the gene set
        
        measure_scores = scores[measure_mask]
        notmeasure_scores = scores[~measure_mask]

        mean_measure = float(measure_scores.mean())
        median_measure = float(measure_scores.median())
        std_measure = float(measure_scores.std())
        mean_notmeasure = float(notmeasure_scores.mean()) if len(notmeasure_scores) > 0 else np.nan
        diff = mean_measure - mean_notmeasure if not np.isnan(mean_notmeasure) else np.nan

        # t-test between measure and not-measure (if non-empty)
        if len(notmeasure_scores) > 0:
            tstat, pval = sp.stats.ttest_ind(measure_scores, notmeasure_scores, equal_var=False, nan_policy='omit')
        else:
            pval = np.nan

        results.append({
            'sample': sample,
            'n_measure_cells': n_measure,
            'pct_measure': pct_measure,
            'n_genes_used': len(genes_in_data),
            'mean_measure_score': mean_measure,
            'median_measure_score': median_measure,
            'std_measure_score': std_measure,
            'mean_notmeasure_score': mean_notmeasure,
            'score_diff_measure_minus_notmeasure': diff,
            'ttest_pval': pval
        })

    # assemble results table
    geneset_scores_by_sample = pd.DataFrame(results).set_index('sample').sort_values('mean_measure_score', ascending=False)
    return geneset_scores_by_sample

# %%
relevant_genesets = ['HALLMARK_TGF_BETA_SIGNALING', 'HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION']
geneset_changes = {}

for geneset_name in relevant_genesets:
   scores_by_sample_recon = compute_geneset_scores(adatas, 'fib_no_monocyte_neighbor', True, 
                                                               genesets[geneset_name], 
                                                                     obsm='X_recon')
   scores_by_sample_recon.columns = [col + '_recon' for col in scores_by_sample_recon.columns]
   scores_by_sample_perturb = compute_geneset_scores(perturbed_adatas, 'fib_no_monocyte_neighbor', True, 
                                                                  genesets[geneset_name], 
                                                                     obsm='X_recon')
   scores_by_sample_perturb.columns = [col + '_perturb' for col in scores_by_sample_perturb.columns]

   merged_scores = pd.merge(scores_by_sample_recon, scores_by_sample_perturb, 
                                       left_index=True, right_index=True)
   
   up_val = (merged_scores['mean_measure_score_perturb'] - merged_scores['mean_measure_score_recon'])
   up_pct = up_val / merged_scores['mean_measure_score_recon'] * 100.0
   geneset_changes[geneset_name] = up_pct
#

# %%
fig, ax = plt.subplots(figsize=(2.5, 2.5))
sns.boxplot(geneset_changes, ax=ax, width=0.5)

def aes_text(s):
    return s.replace('_', '\n')

ax.set_xticklabels([i.get_text().replace('_', '\n') for i in ax.get_xticklabels()])
ax.set_ylabel('Increase in Gene Set Score (%)')
for pos in ['right', 'top']:
    ax.spines[pos].set_visible(False)
# Out:
# C:\Users\lshh\AppData\Local\Temp\ipykernel_13864\1874071492.py:7: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels([i.get_text().replace('_', '\n') for i in ax.get_xticklabels()])

# %%
import pickle as pkl
with open('saved_figure_data/hgsc_fibrosis.pkl', 'wb') as f:
    pkl.dump(geneset_changes, f)

# %%
sp.stats.ttest_1samp(geneset_changes['HALLMARK_TGF_BETA_SIGNALING'].dropna(), 0)
# Out:
# TtestResult(statistic=10.595665984118893, pvalue=1.5691985163568624e-10, df=24)

# %%
sp.stats.ttest_1samp(geneset_changes['HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION'].dropna(), 0)
# Out:
# TtestResult(statistic=9.486945031381044, pvalue=1.3610290432162913e-09, df=24)
