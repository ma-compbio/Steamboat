# %%
import warnings
warnings.filterwarnings("ignore") 
import os, time
import pandas as pd
import numpy as np
import random
import scipy.sparse as sparse
from scipy.sparse import csr_matrix, issparse

from banksy.initialize_banksy import initialize_banksy
from banksy.run_banksy import run_banksy_multiparam
from banksy_utils.color_lists import spagcn_color

import scanpy as sc
import squidpy as sq
from tqdm import tqdm
from sklearn.metrics import normalized_mutual_info_score, adjusted_rand_score

start = time.perf_counter_ns()
random_seed = 1234
cluster_algorithm = 'leiden'
np.random.seed(random_seed)
random.seed(random_seed)

# %%
print(os.environ['CONDA_DEFAULT_ENV'])
# Out:
# py311_torch211_cuda121

# %%
from tqdm.notebook import tqdm

# %%
import sklearn.metrics
import gc

# %% [markdown]
# ## Input-Ouput (IO) Options
# 1. Loading '.h5ad' file
# 2. Saving output images and '.csv' files in 'output_folder'

# %%
adata = sc.read_h5ad("G:/data/slidetags/HumanTonsil_2000.h5ad")

# %%
! mkdir slide_tags_output
# Out:
# A subdirectory or file slide_tags_output already exists.

# %%
adata.obs['dummy'] = 0
adata.obs['dummy'] = adata.obs['dummy'].astype('category')

# %%
coord_keys = ('x', 'y', 'spatial')
num_clusters = 3
annotation_key = 'dummy'
output_folder = 'slide_tags_output/'

# %% [markdown]
# # Run BANKSY using defined parameters

# %%
resolutions = [.22] # clustering resolution for Leiden clustering
pca_dims = [60] # number of dimensions to keep after PCA
lambda_list = [.8] # lambda
k_geom = 15 # 8 spatial neighbours
max_m = 1 # use AGF
nbr_weight_decay = "scaled_gaussian" # can also be "reciprocal", "uniform" or "ranked"

# %%
adata.obs['x'] = adata.obsm['spatial'] [:,0]
adata.obs['y'] = adata.obsm['spatial'] [:,1]

# %%
banksy_dict = initialize_banksy(
    adata,
    coord_keys,
    k_geom,
    nbr_weight_decay=nbr_weight_decay,
    max_m=max_m,
    plt_edge_hist=True,
    plt_nbr_weights=True,
    plt_agf_angles=False,
    plt_theta=False,
)
results_df = run_banksy_multiparam(
adata,
banksy_dict,
lambda_list,
resolutions,
color_list = spagcn_color * 10,
max_m = max_m,
filepath = output_folder,
key = coord_keys,
pca_dims = pca_dims,
annotation_key = annotation_key,
max_labels = 3,
cluster_algorithm = cluster_algorithm,
match_labels = False,
savefig = False,
add_nonspatial = False,
variance_balance = False,
)
adata.obs['banksy'] = results_df['labels'][0].dense

adata.obs[['banksy']].to_csv(f"./slide_tags_output/banksy_domain.csv")
# Out:
# Median distance to closest cell = 13.162909136636577
#
# ---- Ran median_dist_to_nearest_neighbour in 0.02 s ----
#
# ---- Ran generate_spatial_distance_graph in 0.04 s ----
#
# ---- Ran row_normalize in 0.02 s ----
#
# ---- Ran generate_spatial_weights_fixed_nbrs in 0.22 s ----
#
# ----- Plotting Edge Histograms for m = 0 -----
#
# Edge weights (distances between cells): median = 44.51081302877048, mode = 45.529551911354226
#
# ---- Ran plot_edge_histogram in 0.06 s ----
#
#
# Edge weights (weights between cells): median = 0.05772687203986536, mode = 0.04194339834435362
#
# ---- Ran plot_edge_histogram in 0.05 s ----
#
# ---- Ran generate_spatial_distance_graph in 0.06 s ----
#
# ---- Ran theta_from_spatial_graph in 0.06 s ----
#
# ---- Ran row_normalize in 0.02 s ----
#
# ---- Ran generate_spatial_weights_fixed_nbrs in 0.31 s ----
#
# ----- Plotting Edge Histograms for m = 1 -----
#
# Edge weights (distances between cells): median = 63.39150538356155, mode = 69.48229249993267
#
# ---- Ran plot_edge_histogram in 0.06 s ----
#
#
# Edge weights (weights between cells): median = (-0.00020657574774243537+0.00579003983067625j), mode = -0.01104359677740814
#
# ---- Ran plot_edge_histogram in 0.06 s ----
#
# ----- Plotting Weights Graph -----
# Maximum weight: 0.20946115918648545
#
# ---- Ran plot_graph_weights in 0.85 s ----
#
# Maximum weight: (0.09135479832004889+0.0142108386170042j)
#
# ---- Ran plot_graph_weights in 1.71 s ----
#
# Runtime Nov-19-2025-12-09
#
# 2000 genes to be analysed:
# Gene List:
# Index(['FNDC10', 'PRKCZ-AS1', 'AL513477.2', 'PRDM16', 'SLC45A1', 'CA6',
#        'AL139424.3', 'AL031731.1', 'TNFRSF8', 'TNFRSF1B',
#        ...
#        'ZNF185', 'PNMA5', 'SSR4', 'AVPR2', 'F8', 'F8A1', 'AC234781.1',
#        'PCDH11Y', 'TTTY14', 'AC145212.1'],
#       dtype='object', length=2000)
#
# Decay Type: scaled_gaussian
# Weights Object: {'weights': {0: <5778x5778 sparse matrix of type '<class 'numpy.float64'>'
# 	with 86670 stored elements in Compressed Sparse Row format>, 1: <5778x5778 sparse matrix of type '<class 'numpy.complex128'>'
# 	with 173340 stored elements in Compressed Sparse Row format>}}
#
# Nbr matrix | Mean: 0.09 | Std: 0.24
# Size of Nbr | Shape: (5778, 2000)
# Top 3 entries of Nbr Mat:
#
# [[0. 0. 0.]
#  [0. 0. 0.]
#  [0. 0. 0.]]
#
# AGF matrix | Mean: 0.04 | Std: 0.07
# Size of AGF mat (m = 1) | Shape: (5778, 2000)
# Top entries of AGF:
# [[0. 0. 0.]
#  [0. 0. 0.]
#  [0. 0. 0.]]
# Ran 'Create BANKSY Matrix' in 0.04 mins
#
# Cell by gene matrix has shape (5778, 2000)
#
# Scale factors squared: [0.2        0.53333333 0.26666667]
# Scale factors: [0.4472136  0.73029674 0.51639778]
# Shape of BANKSY matrix: (5778, 6000)
# Type of banksy_matrix: <class 'anndata._core.anndata.AnnData'>
#
# Current decay types: ['scaled_gaussian']
#
# Reducing dims of dataset in (Index = scaled_gaussian, lambda = 0.8)
# ==================================================
#
# Setting the total number of PC = 60
# Original shape of matrix: (5778, 6000)
# Reduced shape of matrix: (5778, 60)
# ------------------------------------------------------------
# min_value = -28.78680194578665, mean = -2.3668361349248984e-16, max = 70.98135351224552
#
# Conducting clustering with Leiden Parition
# Decay type: scaled_gaussian
# Neighbourhood Contribution (Lambda Parameter): 0.8
# reduced_pc_60
#
# PCA dims to analyse: [60]
#
# ====================================================================================================
# Setting up partitioner for (nbr decay = scaled_gaussian), Neighbourhood contribution = 0.8, PCA dimensions = 60)
# ====================================================================================================
#
#
# Nearest-neighbour weighted graph (dtype: float64, shape: (5778, 5778)) has 288900 nonzero entries.
# ---- Ran find_nn in 1.66 s ----
#
#
# Nearest-neighbour connectivity graph (dtype: int16, shape: (5778, 5778)) has 288900 nonzero entries.
#
# (after computing shared NN)
# Allowing nearest neighbours only reduced the number of shared NN from 3921270 to 288020.
#
#
# Shared nearest-neighbour (connections only) graph (dtype: int16, shape: (5778, 5778)) has 275137 nonzero entries.
#
# Shared nearest-neighbour (number of shared neighbours as weights) graph (dtype: int16, shape: (5778, 5778)) has 275137 nonzero entries.
#
# sNN graph data:
# [26 29 26 ...  9  6  7]
#
# ---- Ran shared_nn in 0.23 s ----
#
#
# -- Multiplying sNN connectivity by weights --
#
#
# shared NN with distance-based weights graph (dtype: float64, shape: (5778, 5778)) has 275137 nonzero entries.
# shared NN weighted graph data: [0.05047327 0.05049002 0.05083564 ... 0.10017708 0.10173308 0.10711501]
#
# Converting graph (dtype: float64, shape: (5778, 5778)) has 275137 nonzero entries.
# ---- Ran csr_to_igraph in 0.05 s ----
#
#
# Resolution: 0.22
# ------------------------------
#
# ---- Partitioned BANKSY graph ----
# modularity: 0.47
# 3 unique labels:
# [0 1 2]
#
# ---- Ran partition in 0.42 s ----
#
# Computing ARI for annotated labels
# Label Dense [0 1 1 ... 1 0 0]
#
# After sorting Dataframe
# Shape of dataframe: (1, 8)
#                                              decay  lambda_param  num_pcs  \
# scaled_gaussian_pc60_nc0.80_r0.22  scaled_gaussian           0.8       60
#
#                                    resolution  num_labels  \
# scaled_gaussian_pc60_nc0.80_r0.22        0.22           3
#
#                                                                               labels  \
# scaled_gaussian_pc60_nc0.80_r0.22  Label object:\nNumber of labels: 3, number of ...
#
#                                                                                adata  \
# scaled_gaussian_pc60_nc0.80_r0.22  [[[View of AnnData object with n_obs × n_vars ...
#
#                                    ari
# scaled_gaussian_pc60_nc0.80_r0.22  0.0
# Anndata AxisArrays with keys: reduced_pc_60

# %%
adata.obs['banksy'].value_counts()
# Out:
# banksy
# 0    3224
# 1    2475
# 2      79
# Name: count, dtype: int64

# %%
# ari = sklearn.metrics.adjusted_rand_score(adata.obs[annotation_key], adata.obs['banksy'])
# nmi = sklearn.metrics.adjusted_mutual_info_score(adata.obs[annotation_key], adata.obs['banksy'])
# n_clusters = len(adata.obs['banksy'].unique())

# pd.DataFrame([n_clusters, nmi, ari], index=['n_clusters', 'NMI', 'ARI'], columns=[60]).T

# %%
# banksy_res_df = pd.DataFrame([n_clusters, nmi, ari], index=['n_clusters', 'NMI', 'ARI'], columns=[60]).T
# banksy_res_df.to_csv("../Steamboat/revised/saved_results/slide_tags_banksy_res_df.csv")
# banksy_res_df
